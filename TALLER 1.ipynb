# %%
print("Hola mundo Soy juan")
# Out:
# Hola mundo Soy juan

# %% [markdown]
# **VARIABLES**

# %%
nombre = "juan leguizamo"
print(nombre)
telefono = 4552890
print(telefono)
# Out:
# juan leguizamo
# 4552890

# %% [markdown]
# TALLER

# %%
nombre_per = input("Digite su Nombre")
print(nombre_per)
Numero_ID = input("digite su nuero de identificacion")
print(Numero_ID)
telefono_per = input("Digite numero")
direccion = input ("digite direccion")
print(telefono_per)
edad = input("numeo de años")
print(edad)
estado_civil = input("soltero,casado,union libre, divorciado o viudo")
print(estado_civil)
numero_de_hijos = input("numeros de hijos")
print(numero_de_hijos)
estatura = input("estaura en centimetros")
print(estatura)
fecha_de_contratacion = input("dia/mes/años")
print(fecha_de_contratacion)
sueldo_basico = input("valor en numeros")
print(sueldo_basico)
dias_laborados = input("numero de dias")
print(dias_laborados )

# %%
nombre_per =("pedro perez")
print(nombre_per)
Numero_ID =("10336919999")
print(Numero_ID)
telefono_per =("3131231313")
print(telefono_per)
edad =("18")
print(edad)
estado_civil =("divorciado")
print(estado_civil)
numero_de_hijos =("7")
print(numero_de_hijos)
estatura =("2.30")
print(estatura)
fecha_de_contratacion =("12/01/2023")
print(fecha_de_contratacion)
sueldo_basico = ("1200000")
print(sueldo_basico)
dias_laborados = ("365")
print(dias_laborados )
# Out:
# pedro perez
# 10336919999
# 3131231313
# 18
# divorciado
# 7
# 2.30
# 12/01/2023
# 1200000
# 365

# %%
Venta = float (input(total))
iva = *0.19
# la suma del iva con la venta
total = Venta + iva
# muestro por pantalla en total con el iva 
print (el Ivan es=${:,.})
