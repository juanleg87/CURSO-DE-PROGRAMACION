# %% [markdown]
# #**OPERADORES MATEMÁTICOS EN PTYHON**
# Programas para operaciones basicas

# %%
num1 = 7
num2 = 4
res = num1 + num2
print(res)
# Out:
# 11

# %%
# Pro default input() - str
num1 = int(input("Digite el número 1: "))
num2 = int(input("Digite el número 2: "))
res = num1 + num2
print("La suma de {} y {} es= {}".format(num1, num2, res))
print(f"La suma de {num1} y {num2} es= {res}")
# Out:
# Digite el número 1: 10
# Digite el número 2: 10
# La suma de 10 y 10 es= 20
# La suma de 10 y 10 es= 20

# %% [markdown]
# **CALCULADORA** + - * /

# %%
num1 = int(input("Digite el número 1: "))
num2 = int(input("Digite el número 2: "))

suma = num1 + num2
resta = num1 - num2
multi = num1 * num2
divi = num1 / num2

print("\n EL resultao de la SUMA es= {}".format(suma))
print("\n EL resultao de la RESTA es= {}".format(resta))
print(f"\n EL resutlado de la MULTIPLICACIÓN es= {multi}")
print(f"\n EL resutlado de la DIVISIÓN es= {divi}")
# Out:
# Digite el número 1: 10
# Digite el número 2: 5
#
#  EL resultao de la SUMA es= 15
#
#  EL resultao de la RESTA es= 5
#
#  EL resutlado de la MULTIPLICACIÓN es= 50
#
#  EL resutlado de la DIVISIÓN es= 2.0

# %% [markdown]
# Se recibe una venta por concepto de un prodcuto se requiere aplicar el IVA (19%) y conocer el total a pagar con el IVA Incluido

# %%
# variable para capturar la venta
venta = float(input("¿Cuanto fue el total de la compra?: "))
# Cálculo del iva
iva = venta * 0.1 
# suma del iva con la venta
total = venta + iva
# Muestro por pantalla el total con el iva
print("EL IVA es= ${:,.0f} y el total a pagar es=${:,.0f}".format(iva, total ))
# Out:
# ¿Cuanto fue el total de la compra?: 250000
# EL IVA es= $47,500 y el total a pagar es=$297,500

# %% [markdown]
# Se requiere conocer el promerdio general de una materia que está dada por tres calificaciones

# %%
cal1 = float(input("Digite la calificaicón 1: "))
cal2 = float(input("Digite la calificaicón 2: "))
cal3 = float(input("Digite la calificaicón 3: "))

prom = round((cal1 + cal2 + cal3) / 3, 2)

print(f"El promedio es= {prom}")
# Out:
# Digite la calificaicón 1: 1.2
# Digite la calificaicón 2: 3.7
# Digite la calificaicón 3: 4.5
# El promedio es= 3.13

# %% [markdown]
# **Taller**
# https://drive.google.com/file/d/1jFH9DgCRha_dn9JG7c_jjTpeE5x5kK3d/view?usp=sharing

# %% [markdown]
# Un vendedor recibe un sueldo base más un 10% extra por
# comisión de sus ventas, el vendedor desea saber cuánto
# dinero obtendrá por concepto de comisiones por las tres
# ventas que realiza en el mes y el total que recibirá en
# el mes tomando en cuenta su sueldo base y comisiones.

# %%
# variable para capturar la sueldo + comision
Sueldo_base = float(input("¿total sueldo mas 10% de comision?: "))
# Cálculo del 10%
porcentaje = Sueldo_base * 0.1 
# suma del 10% con el sueldo base
total = Sueldo_base + porcentaje
# Muestro por pantalla el total con el iva
print("porcentaje es= ${:,.0f} y el total a pagar es=${:,.0f}".format(porcentaje, total ))

# %% [markdown]
# 2. Una tienda ofrece un descuento del 15% sobre el total
# de la compra y un cliente desea saber cuánto deberá
# pagar finalmente por su compra.

# %%
# variable para capturar la compra - 15 de descuento
compra = float(input("¿total a pagar con el 15% de descuento?: "))
# Cálculo del 15%
descuento = Sueldo_base * 0.15
# resta del 15% con la compra
total = compra - descuento
# Muestro por pantalla total a pagar
print("descuento es= ${:,.0f} y el total a pagar es=${:,.0f}".format(descuento, total ))
# Out:
# ¿total a pagar con el 15% de descuento?: 100
# descuento es= $15 y el total a pagar es=$85

# %% [markdown]
# 3. Un alumno desea saber cuál será su calificación final en
# la materia de Algoritmos. Dicha calificación se compone
# de tres exámenes parciales.

# %%
cal1 = float(input("Digite la calificaicón 1: "))
cal2 = float(input("Digite la calificaicón 2: "))
cal3 = float(input("Digite la calificaicón 3: "))

prom = round((cal1 + cal2 + cal3) / 3, 2)

print(f"El promedio es= {prom}")
# Out:
# Digite la calificaicón 1: 2
# Digite la calificaicón 2: 3
# Digite la calificaicón 3: 5
# El promedio es= 3.33

# %% [markdown]
# 4. Un maestro desea saber qué porcentaje de hombres y que
# porcentaje de mujeres hay en un grupo de estudiantes.

# %%
HOMBRES = INT(input(porcentaje))
total
